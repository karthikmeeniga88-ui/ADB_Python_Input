# %%
INGESTION_CONFIG = [
    {
        "source": "crm",
        "path": "/Volumes/workspace/default/input/crm/cust_info.csv",
        "table": "crm_cust_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/default/input/crm/prd_info.csv",
        "table": "crm_prd_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/default/input/crm/sales_details.csv",
        "table": "crm_sales_details"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/default/input/ep/CUST_AZ12.csv",
        "table": "erp_cust_az12"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/default/input/ep/LOC_A101.csv",
        "table": "erp_loc_a101"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/default/input/ep/PX_CAT_G1V2.csv",
        "table": "erp_px_cat_g1v2"
    }
]

# %%
for item in INGESTION_CONFIG:
    print(f"Ingesting {item['source']} → workspace.default.{item['table']}")

    df = (
        spark.read
             .option("header", "true")
             .option("inferSchema", "true")
             .csv(item["path"])
    )

    (
        df.write
          .mode("overwrite")
          .format("delta")
          .saveAsTable(f"workspace.default.{item['table']}")
    )

# %%
# %sql
select * from workspace.default.crm_cust_info
